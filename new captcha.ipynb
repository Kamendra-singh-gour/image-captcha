# %%
from tkinter import *
from tkinter import ttk
from PIL import ImageTk , Image
import random
a=0
b=0
window=1
window1=1
window2=1
class One:
    root = 1
    List1 = [0 , 1 , 2]
    List2 = [0 , 1 , 2]
    List3 = [0 , 1 , 2]

    #function one which will have definitin of all the functions

    def function_1(self):
        One.root = Tk ()
        One.root.title ("IMAGE CAPTCHA")

     #creating frames basically 2 one for text and another for images


        frame1 = LabelFrame (One.root , width=60 , height=50 , bg='blue' , relief='raised')
        frame1.grid (row=0 , column=0)
        frame = ttk.LabelFrame (One.root)
        frame.grid (row=1 , column=0)
        l = Label (frame1 , text="Click on all images of car                  " , font=(None , 15) , bg='blue' ,
                   fg='white')
        l.grid (rowspan=5 , column=0 , sticky=W)


        # extending rows

        l1 = Label (frame1 , text='' , bg='blue' , fg='white')
        l1.grid (rowspan=2 , column=0)
        l2 = Label (frame1 , text='' , bg='blue' , fg='white')
        l2.grid (rowspan=2 , column=0)

        # opening images of car

        img = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a.png"))
        img1 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a1.png"))
        img2 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a2.png"))
        img3 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a3.png"))
        img4 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a4.png"))
        img5 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a5.png"))
        img6 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a6.png"))
        img7 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a7.png"))
        img8 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.car\\a8.png"))

        # function to ceate a second new window

        def new():
            global a
            global b
            a=0
            b=0
            One.root.withdraw()
            global window
            window = Tk ()
            window.title ("IMAGE CAPTCHA")
            # root.geometry("500,500")
            frame1 = LabelFrame (window , width=60 , height=50 , bg='blue' , relief='raised')
            frame1.grid (row=0 , column=0)
            frame = ttk.LabelFrame (window)
            frame.grid (row=1 , column=0)
            l = Label (frame1 , text="Click on all images of burger                    " , font=(None , 15) , bg='blue' ,
                       fg='white')
            l.grid (rowspan=5 , column=0 , sticky=W)

            # extending rows

            l1 = Label (frame1 , text='' , bg='blue' , fg='white')
            l1.grid (rowspan=2 , column=0)
            l2 = Label (frame1 , text='' , bg='blue' , fg='white')
            l2.grid (rowspan=2 , column=0)

            # opening images of burger

            Img = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c.png"),master=window)
            Img1 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c1.png"),master=window)
            Img2 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c2.png"),master=window)
            Img3 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c3.png"),master=window)
            Img4 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c4.png"),master=window)
            Img5 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c5.png"),master=window)
            Img6 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c6.png"),master=window)
            Img7 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c7.png"),master=window)
            Img8 = ImageTk.PhotoImage (Image.open ("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.burger\\c8.png"),master=window)

            # function to ceate a third new window

            def new1():
                global a
                global b
                a = 0
                b = 0
                global window
                window.withdraw()
                global window1
                window1 = Tk()
                window1.title("IMAGE CAPTCHA")
                # root.geometry("500,500")
                frame1 = LabelFrame(window1, width=60, height=50, bg='blue', relief='raised')
                frame1.grid(row=0, column=0)
                frame = ttk.LabelFrame(window1)
                frame.grid(row=1, column=0)
                l = Label(frame1, text="Click on all images of Zeebra Crossing          ", font=(None, 15), bg='blue',
                          fg='white')
                l.grid(rowspan=5, column=0, sticky=W)

                # extending rows of traffic light

                l1 = Label(frame1, text='', bg='blue', fg='white')
                l1.grid(rowspan=2, column=0)
                l2 = Label(frame1, text='', bg='blue', fg='white')
                l2.grid(rowspan=2, column=0)

                # opening images of TRAFFIC LIGHTS

                Img = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z.png"),
                                         master=window1)
                Img1 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z1.png"),
                                          master=window1)
                Img2 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z2.png"),
                                          master=window1)
                Img3 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z3.png"),
                                          master=window1)
                Img4 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z4.png"),
                                          master=window1)
                Img5 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z5.png"),
                                          master=window1)
                Img6 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z6.png"),
                                          master=window1)
                Img7 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z6.png"),
                                          master=window1)
                Img8 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.zeebra\\z8.png"),
                                          master=window1)

                # function to ceate a forth new window

                def new2():
                    global a
                    global b
                    a = 0
                    b = 0
                    global window1
                    window1.withdraw()
                    global window2
                    window2 = Tk()
                    window2.title("IMAGE CAPTCHA")

                    #creating two labels again for fourth page

                    frame1 = LabelFrame(window2, width=60, height=50, bg='blue', relief='raised')
                    frame1.grid(row=0, column=0)
                    frame = ttk.LabelFrame(window2)
                    frame.grid(row=1, column=0)
                    l = Label(frame1, text="Click on all images of bus                    ", font=(None, 15), bg='blue',
                              fg='white')
                    l.grid(rowspan=5, column=0, sticky=W)

                    # extending rows of bus captcha

                    l1 = Label(frame1, text='', bg='blue', fg='white')
                    l1.grid(rowspan=2, column=0)
                    l2 = Label(frame1, text='', bg='blue', fg='white')
                    l2.grid(rowspan=2, column=0)

                    # opening images of buses

                    Img = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b.png"),
                                             master=window2)
                    Img1 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b1.png"),
                                              master=window2)
                    Img2 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b2.png"),
                                              master=window2)
                    Img3 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b3.png"),
                                              master=window2)
                    Img4 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b4.png"),
                                              master=window2)
                    Img5 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b5.png"),
                                              master=window2)
                    Img6 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b6.png"),
                                              master=window2)
                    Img7 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b7.png"),
                                              master=window2)
                    Img8 = ImageTk.PhotoImage(Image.open("C:\\Users\\SR\\Documents\\Custom Office Templates\\image captcha\\png.bus\\b8.png"),
                                              master=window2)


                    # creating randow grid for bus images
                    List_1 = [0, 1, 2]
                    List_2 = [0, 1, 2]
                    List_3 = [0, 1, 2]

                    # function to tell cars apart
                    def action():
                        global a
                        a = a + 1

                    def action1():
                        global b
                        b = b + 1

                    def verify():
                        global a
                        global b
                        if a % 4 == 0 and b == 0:
                            print("access granted")
                        else:
                            print("access denied")

                    #creating random grid for bus images

                    def allocate1():
                        if len(List_1) > 0:
                            random.shuffle(List_1)
                            s = List_1.pop()
                            return s

                    def allocate2():
                        if len(List_2) > 0:
                            random.shuffle(List_2)
                            s = List_2.pop()
                            return s

                    def allocate3():
                        if len(List_3) > 0:
                            random.shuffle(List_3)
                            s = List_3.pop()
                            return s

                    # creating images as buttons for buses

                    cutton = ttk.Button(frame, image=Img, command=lambda: action())
                    cutton.grid(row=0, column=allocate1(), sticky=W, padx=1, pady=1)

                    cutton1 = ttk.Button(frame, image=Img4, command=lambda: action1())
                    cutton1.grid(row=0, column=allocate1(), sticky=W, padx=1, pady=1)

                    cutton2 = ttk.Button(frame, image=Img5, command=lambda: action1())
                    cutton2.grid(row=0, column=allocate1(), sticky=W, padx=1, pady=1)

                    cutton3 = ttk.Button(frame, image=Img6, command=lambda: action1())
                    cutton3.grid(row=1, column=allocate2(), sticky=W, padx=1, pady=1)

                    cutton4 = ttk.Button(frame, image=Img2, command=lambda: action())
                    cutton4.grid(row=1, column=allocate2(), sticky=W, padx=1, pady=1)

                    cutton5 = ttk.Button(frame, image=Img1, command=lambda: action())
                    cutton5.grid(row=1, column=allocate2(), sticky=W, padx=1, pady=1)

                    cutton6 = ttk.Button(frame, image=Img3, command=lambda: action())
                    cutton6.grid(row=2, column=allocate3(), sticky=W, padx=1, pady=1)

                    cutton7 = ttk.Button(frame, image=Img7, command=lambda: action1())
                    cutton7.grid(row=2, column=allocate3(), sticky=W, padx=1, pady=1)

                    cutton8 = ttk.Button(frame, image=Img8, command=lambda: action1())
                    cutton8.grid(row=2, column=allocate3(), sticky=W, padx=1, pady=1)

                    cutton_9 = Button(frame, text='      VERIFY      ', font=(None, 10, 'bold'), bg='blue', fg='white',
                                      command=lambda: verify())
                    cutton_9.grid(row=4, column=2, sticky=W, padx=5, pady=5)

                    cutton_10 = Button(frame, text='   DEAD END    ', font=(None, 10, 'bold'), bg='blue', fg='white')
                    cutton_10.grid(row=4, column=1, sticky=W, padx=5, pady=5)

                    window2.mainloop()
                    ##last window has been ended here!##

                # creating randow grid for traffic light images

                List_1 = [0, 1, 2]
                List_2 = [0, 1, 2]
                List_3 = [0, 1, 2]

                # function to tell traffic light apart

                def action():
                    global a
                    a = a + 1

                def action1():
                    global b
                    b = b + 1

                def verify():
                    global a
                    global b
                    if a % 4 == 0 and b == 0:
                        print("access granted")
                    else:
                        print("access denied")

                 #creating functions for random allocation

                def allocate1():
                    if len(List_1) > 0:
                        random.shuffle(List_1)
                        s = List_1.pop()
                        return s

                def allocate2():
                    if len(List_2) > 0:
                        random.shuffle(List_2)
                        s = List_2.pop()
                        return s

                def allocate3():
                    if len(List_3) > 0:
                        random.shuffle(List_3)
                        s = List_3.pop()
                        return s

                # creating images as buttons for traffic lights

                cutton = ttk.Button(frame, image=Img, command=lambda: action())
                cutton.grid(row=0, column=allocate1(), sticky=W, padx=1, pady=1)

                cutton1 = ttk.Button(frame, image=Img4, command=lambda: action1())
                cutton1.grid(row=0, column=allocate1(), sticky=W, padx=1, pady=1)

                cutton2 = ttk.Button(frame, image=Img5, command=lambda: action1())
                cutton2.grid(row=0, column=allocate1(), sticky=W, padx=1, pady=1)

                cutton3 = ttk.Button(frame, image=Img6, command=lambda: action())
                cutton3.grid(row=1, column=allocate2(), sticky=W, padx=1, pady=1)

                cutton4 = ttk.Button(frame, image=Img2, command=lambda: action1())
                cutton4.grid(row=1, column=allocate2(), sticky=W, padx=1, pady=1)

                cutton5 = ttk.Button(frame, image=Img1, command=lambda: action())
                cutton5.grid(row=1, column=allocate2(), sticky=W, padx=1, pady=1)

                cutton6 = ttk.Button(frame, image=Img3, command=lambda: action1())
                cutton6.grid(row=2, column=allocate3(), sticky=W, padx=1, pady=1)

                cutton7 = ttk.Button(frame, image=Img7, command=lambda: action())
                cutton7.grid(row=2, column=allocate3(), sticky=W, padx=1, pady=1)

                cutton8 = ttk.Button(frame, image=Img8, command=lambda: action1())
                cutton8.grid(row=2, column=allocate3(), sticky=W, padx=1, pady=1)

                cutton_9 = Button(frame, text='      VERIFY      ', font=(None, 10,'bold'), bg='blue', fg='white',
                                  command=lambda: verify())
                cutton_9.grid(row=4, column=2, sticky=W, padx=5, pady=5)

                cutton_10 = Button(frame, text='   TRY NEXT    ', font=(None, 10,'bold'), bg='blue', fg='white',command=lambda : new2())
                cutton_10.grid(row=4, column=1, sticky=W, padx=5, pady=5)

                window1.mainloop()
                ##third window has been ended here!##

            # creating randow grid for car images
            List_1 = [0 , 1 , 2]
            List_2 = [0 , 1 , 2]
            List_3 = [0 , 1 , 2]

            #function to tell cars apart
            def action():
                global a
                a = a + 1

            def action1():
                global b
                b = b + 1

            def verify():
                global a
                global b
                if a % 6 == 0 and b == 0:
                    print ("access granted")
                else:
                    print ("access denied")

            #creating functions for random allocation

            def allocate1():
                if len (List_1) > 0:
                    random.shuffle (List_1)
                    s = List_1.pop ()
                    return s

            def allocate2():
                if len (List_2) > 0:
                    random.shuffle (List_2)
                    s = List_2.pop ()
                    return s

            def allocate3():
                if len (List_3) > 0:
                    random.shuffle (List_3)
                    s = List_3.pop ()
                    return s

            # creating images of car as buttons

            cutton = ttk.Button (frame , image=Img,command=lambda:action())
            cutton.grid (row=0 , column=allocate1 () , sticky=W , padx=1 , pady=1)

            cutton1 = ttk.Button (frame , image=Img4,command=lambda:action())
            cutton1.grid (row=0 , column=allocate1 () , sticky=W , padx=1 , pady=1)

            cutton2 = ttk.Button (frame , image=Img7,command=lambda:action1())
            cutton2.grid (row=0 , column=allocate1 () , sticky=W , padx=1 , pady=1)

            cutton3 = ttk.Button (frame , image=Img6,command=lambda:action1())
            cutton3.grid (row=1 , column=allocate2 () , sticky=W , padx=1 , pady=1)

            cutton4 = ttk.Button (frame , image=Img2,command=lambda:action())
            cutton4.grid (row=1 , column=allocate2 () , sticky=W , padx=1 , pady=1)

            cutton5 = ttk.Button (frame , image=Img1,command=lambda:action())
            cutton5.grid (row=1 , column=allocate2 () , sticky=W , padx=1, pady=1)

            cutton6 = ttk.Button (frame , image=Img3,command=lambda:action())
            cutton6.grid (row=2 , column=allocate3 () , sticky=W , padx=1 , pady=1)

            cutton7 = ttk.Button (frame , image=Img5,command=lambda:action1())
            cutton7.grid (row=2 , column=allocate3 () , sticky=W , padx=1 , pady=1)

            cutton8 = ttk.Button (frame , image=Img8,command=lambda:action())
            cutton8.grid (row=2 , column=allocate3 () , sticky=W , padx=1 , pady=1)

            cutton_9 = Button(frame , text='      VERIFY      ' , font=(None , 10,'bold') , bg='blue' , fg='white',command=lambda:verify())
            cutton_9.grid (row=4 , column=2 , sticky=W , padx=5 , pady=5)

            cutton_10 = Button(frame , text='    TRY NEXT   ' , font=(None , 10,'bold') , bg='blue' , fg='white',command=lambda:new1())
            cutton_10.grid (row=4 , column=1 , sticky=E , padx=5 , pady=5)

            window.mainloop ()
            ##second window has been ended here!##

        # creating randow grid for allocation of cake images

        def allocate1():
            if len (One.List1) > 0:
                random.shuffle (One.List1)
                s = One.List1.pop ()
                return s

        def allocate2():
            if len (One.List2) > 0:
                random.shuffle (One.List2)
                s = One.List2.pop ()
                return s

        def allocate3():
            if len (One.List3) > 0:
                random.shuffle (One.List3)
                s = One.List3.pop ()
                return s

       #function to grant the access

        def action():
            global a
            a=a+1
        def action1():
            global b
            b=b+1
        def verify():
            global a
            global b
            if a%4==0 and b==0:
                print("access granted")
            else:
                print("access denied")

        # creating images of cake as buttons

        button = ttk.Button (frame , image=img,command=lambda:action())
        button.grid (row=0 , column=allocate1 () , sticky=W , padx=1 , pady=1)  

        button1 = ttk.Button (frame , image=img4,command=lambda:action1())
        button1.grid (row=0 , column=allocate1 () , sticky=W , padx=1 , pady=1)

        button2 = ttk.Button (frame , image=img1,command=lambda:action())
        button2.grid (row=0 , column=allocate1 () , sticky=W , padx=1 , pady=1)

        button3 = ttk.Button (frame , image=img5,command=lambda:action1())
        button3.grid (row=1 , column=allocate2 () , sticky=W , padx=1 , pady=1)

        button4 = ttk.Button (frame , image=img2,command=lambda:action())
        button4.grid (row=1 , column=allocate2 () , sticky=W , padx=1 , pady=1)

        button5 = ttk.Button (frame , image=img6,command=lambda:action1())
        button5.grid (row=1 , column=allocate2 () , sticky=W , padx=1 , pady=1)

        button6 = ttk.Button (frame , image=img3,command=lambda:action())
        button6.grid (row=2 , column=allocate3 () , sticky=W , padx=1 , pady=1)

        button7 = ttk.Button (frame , image=img7,command=lambda:action1())
        button7.grid (row=2 , column=allocate3 () , sticky=W , padx=1 , pady=1)

        button8 = ttk.Button (frame , image=img8,command=lambda:action1())
        button8.grid (row=2 , column=allocate3 () , sticky=W , padx=1 , pady=1)

        button9 = Button (frame , text='      VERIFY      ' , font=(None , 10,'bold') , bg='blue' , fg='white',relief="raised",command=verify)
        button9.grid (row=4 , column=2 , sticky=W , padx=5 , pady=5)

        button10 = Button (frame , text='    TRY  NEXT  ' , font=(None , 10,'bold') , bg='blue' , fg='white' ,relief="raised", command=new)
        button10.grid (row=4 , column=1 , sticky=W , padx=5 , pady=5)

        One.root.mainloop ()
        ##first window has been ended here!##

A = One ()
A.function_1 ()
# Out:
# access denied
